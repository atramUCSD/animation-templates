# %%
import pandas as pd

# %%
# Create data frame
df = pd.read_json('connectionRating.json', orient = 'columns')
df
# Out:
#                                              connections
# 0      {'synset': 5995898, 'rating': 1.0, 'words': ['...
# 1      {'synset': 1558749, 'rating': 0.60000000000000...
# 2      {'synset': 1421122, 'rating': 0.17204301075268...
# 3      {'synset': 627693, 'rating': 1.1, 'words': ['m...
# 4      {'synset': 2298632, 'rating': 0.44444444444444...
# 5      {'synset': 3082656, 'rating': 1.11111111111111...
# 6      {'synset': 2749690, 'rating': 1.88888888888888...
# 7      {'synset': 434097, 'rating': 1.776209677419354...
# 8      {'synset': 7175241, 'rating': 0.18361153262518...
# 9      {'synset': 4804306, 'rating': 0.5, 'words': ['...
# 10     {'synset': 2673022, 'rating': 1.83333333333333...
# 11     {'synset': 1968352, 'rating': 1.5, 'words': ['...
# 12     {'synset': 376106, 'rating': 0.875, 'words': [...
# 13     {'synset': 1860465, 'rating': 0.10526315789473...
# 14     {'synset': 2688794, 'rating': 0.15506329113924...
# ...

# %%
import json

with open('Desktop/xiaProj/connectionRating.json') as cRatings:
  data = json.load(cRatings)

print(data)
